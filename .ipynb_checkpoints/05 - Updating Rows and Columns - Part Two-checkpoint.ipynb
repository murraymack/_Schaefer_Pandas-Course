# %%
# https://www.youtube.com/watch?v=DCDe29sIKcE&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=5
import pandas as pd
import os
import numpy as np

data_path, schema_path = 'data/news.csv', 'data/news_schema.csv'
df, schema_df = pd.read_csv(data_path), pd.read_csv(schema_path)

# %%
df.head()
# Out:
#    Unnamed: 0                   authors  \
# 0           0              ['Cbc News']
# 1           1              ['Cbc News']
# 2           2  ['The Associated Press']
# 3           3              ['Cbc News']
# 4           4              ['Cbc News']
#
#                                                title         publish_date  \
# 0  Coronavirus a 'wake-up call' for Canada's pres...  2020-03-27 08:00:00
# 1  Yukon gov't names 2 possible sources of corona...  2020-03-27 01:45:00
# 2  U.S. Senate passes $2T coronavirus relief package  2020-03-26 05:13:00
# 3  Coronavirus: The latest in drug treatment and ...  2020-03-27 00:36:00
# 4  The latest on the coronavirus outbreak for Mar...  2020-03-26 20:57:00
#
#                                          description  \
# 0  Canadian pharmacies are limiting how much medi...
# 1  The Yukon government has identified two places...
# 2  The Senate has passed an unparalleled $2.2 tri...
# 3  Scientists around the world are racing to find...
# ...

# %%
import numpy as np
df['numbers'] = 0
df['numbers'] = df['numbers'].apply(lambda x: int(100000*np.random.rand(1)))

# %%
df
# Out:
#       Unnamed: 0                                            authors  \
# 0              0                                       ['Cbc News']
# 1              1                                       ['Cbc News']
# 2              2                           ['The Associated Press']
# 3              3                                       ['Cbc News']
# 4              4                                       ['Cbc News']
# 5              5  ['Mark Gollom Is A Toronto-Based Reporter With...
# 6              6                                       ['Cbc News']
# 7              7                           ['The Associated Press']
# 8              8                                ['Thomson Reuters']
# 9              9  ['Leah Hendry Is A Tv', 'Radio', 'Online Journ...
# 10            10  ['Reporter', 'Web Writer For Cbc Saskatoon', '...
# 11            11  ['Jorge Barrera Is A Caracas-Born', 'Award-Win...
# 12            12  ['Colleen M. Flood Is Director Of The Centre F...
# ...

# %%
df.rename(columns={'numbers':'salary_USD'}, inplace=True)
df
# Out:
#       Unnamed: 0                                            authors  \
# 0              0                                       ['Cbc News']
# 1              1                                       ['Cbc News']
# 2              2                           ['The Associated Press']
# 3              3                                       ['Cbc News']
# 4              4                                       ['Cbc News']
# 5              5  ['Mark Gollom Is A Toronto-Based Reporter With...
# 6              6                                       ['Cbc News']
# 7              7                           ['The Associated Press']
# 8              8                                ['Thomson Reuters']
# 9              9  ['Leah Hendry Is A Tv', 'Radio', 'Online Journ...
# 10            10  ['Reporter', 'Web Writer For Cbc Saskatoon', '...
# 11            11  ['Jorge Barrera Is A Caracas-Born', 'Award-Win...
# 12            12  ['Colleen M. Flood Is Director Of The Centre F...
# ...

# %%
df['authors'] = df['authors'].map({"['Cbc News']":"Cbc News"})
df
# Out:
#       Unnamed: 0   authors                                              title  \
# 0              0  Cbc News  Coronavirus a 'wake-up call' for Canada's pres...
# 1              1  Cbc News  Yukon gov't names 2 possible sources of corona...
# 2              2       NaN  U.S. Senate passes $2T coronavirus relief package
# 3              3  Cbc News  Coronavirus: The latest in drug treatment and ...
# 4              4  Cbc News  The latest on the coronavirus outbreak for Mar...
# 5              5       NaN  'Worse' pandemic on horizon unless world deals...
# 6              6  Cbc News  What you need to know about COVID-19 in Ottawa...
# 7              7       NaN  Michigan hospitals jammed as coronavirus cases...
# 8              8       NaN    U.S. coronavirus cases now highest in the world
# 9              9       NaN  'Avoid the emergency' pleads Jewish General, a...
# 10            10       NaN  COVID-19 in Sask: Province announces first 3 c...
# ...

# %%
data_path = 'data/news.csv'
df = pd.read_csv(data_path)
df['numbers'] = 0
df['numbers'] = df['numbers'].apply(lambda x: int(100000*np.random.rand(1)))

# %%
df['authors'] = df['authors'].replace({"['Cbc News']":"Cbc News"})
df
# Out:
#       Unnamed: 0                                            authors  \
# 0              0                                           Cbc News
# 1              1                                           Cbc News
# 2              2                           ['The Associated Press']
# 3              3                                           Cbc News
# 4              4                                           Cbc News
# 5              5  ['Mark Gollom Is A Toronto-Based Reporter With...
# 6              6                                           Cbc News
# 7              7                           ['The Associated Press']
# 8              8                                ['Thomson Reuters']
# 9              9  ['Leah Hendry Is A Tv', 'Radio', 'Online Journ...
# 10            10  ['Reporter', 'Web Writer For Cbc Saskatoon', '...
# 11            11  ['Jorge Barrera Is A Caracas-Born', 'Award-Win...
# 12            12  ['Colleen M. Flood Is Director Of The Centre F...
# ...

# %%
df['authors'] = df['authors'].str.replace("[",'')
df
# Out:
#       Unnamed: 0                                            authors  \
# 0              0                                           Cbc News
# 1              1                                           Cbc News
# 2              2                            'The Associated Press']
# 3              3                                           Cbc News
# 4              4                                           Cbc News
# 5              5  'Mark Gollom Is A Toronto-Based Reporter With ...
# 6              6                                           Cbc News
# 7              7                            'The Associated Press']
# 8              8                                 'Thomson Reuters']
# 9              9  'Leah Hendry Is A Tv', 'Radio', 'Online Journa...
# 10            10  'Reporter', 'Web Writer For Cbc Saskatoon', 'S...
# 11            11  'Jorge Barrera Is A Caracas-Born', 'Award-Winn...
# 12            12  'Colleen M. Flood Is Director Of The Centre Fo...
# ...

# %%
df['authors'] = df['authors'].str.replace("]",'')
df
# Out:
#       Unnamed: 0                                            authors  \
# 0              0                                           Cbc News
# 1              1                                           Cbc News
# 2              2                             'The Associated Press'
# 3              3                                           Cbc News
# 4              4                                           Cbc News
# 5              5  'Mark Gollom Is A Toronto-Based Reporter With ...
# 6              6                                           Cbc News
# 7              7                             'The Associated Press'
# 8              8                                  'Thomson Reuters'
# 9              9  'Leah Hendry Is A Tv', 'Radio', 'Online Journa...
# 10            10  'Reporter', 'Web Writer For Cbc Saskatoon', 'S...
# 11            11  'Jorge Barrera Is A Caracas-Born', 'Award-Winn...
# 12            12  'Colleen M. Flood Is Director Of The Centre Fo...
# ...

# %%
df['authors'] = df['authors'].str.replace("'",'')
df
# Out:
#       Unnamed: 0                                            authors  \
# 0              0                                           Cbc News
# 1              1                                           Cbc News
# 2              2                               The Associated Press
# 3              3                                           Cbc News
# 4              4                                           Cbc News
# 5              5  Mark Gollom Is A Toronto-Based Reporter With C...
# 6              6                                           Cbc News
# 7              7                               The Associated Press
# 8              8                                    Thomson Reuters
# 9              9  Leah Hendry Is A Tv, Radio, Online Journalist ...
# 10            10  Reporter, Web Writer For Cbc Saskatoon, Story ...
# 11            11  Jorge Barrera Is A Caracas-Born, Award-Winning...
# 12            12  Colleen M. Flood Is Director Of The Centre For...
# ...
